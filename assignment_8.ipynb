# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
X = iris.data
y = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0])

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 1.0

# %%
for feature in iris.feature_names:
    rules = X_train.groupby(X_train[feature].round())["target"].agg(lambda x: x.mode()[0])
    
    preds = X_test[feature].round().map(rules)
    preds = preds.fillna(rules.mode()[0])

    acc = accuracy_score(y_test, preds)
    
    if acc > best_accuracy:
        best_accuracy = acc
        best_feature = feature
        best_rules = rules

print("Best Feature (OneR):", best_feature)
print("Accuracy:", best_accuracy)
print("Rules:\n", best_rules)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 for feature in iris.feature_names:
# ----> 2     rules = X_train.groupby(X_train[feature].round())["target"].agg(lambda x: x.mode()[0])
#       4     preds = X_test[feature].round().map(rules)
#       5     preds = preds.fillna(rules.mode()[0])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'groupby'
